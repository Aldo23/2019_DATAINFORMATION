# %%
#WEBSITE FOR DATA 
url='https://www.data.gov/'

# %%
#standard import 
import numpy as np
from pandas import Series,DataFrame
import pandas as pd

# %%
#stats import now
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#OPEN TEXT EDITOR AND PUT SOME LETTERS AND NUMBERS AND SAVE IT IN YOUR PYTHON FOLDER

# %%
url='https://opendata-ajuntament.barcelona.cat/data/en/dataset/est-demo-canvi-domicili/resource/5e78ab42-3f08-4fba-bf15-c2d020165385'
dframe = pd.read_csv('2014_canvis-de-domicili.csv')
dframe
# Out:
#        Any  Codi_Districte_baixa  Nom_Districte_baixa  Codi_Barri_baixa  \
# 0     2014                     1         Ciutat Vella                 1
# 1     2014                     1         Ciutat Vella                 2
# 2     2014                     1         Ciutat Vella                 3
# 3     2014                     1         Ciutat Vella                 4
# 4     2014                     2             Eixample                 5
# 5     2014                     2             Eixample                 6
# 6     2014                     2             Eixample                 7
# 7     2014                     2             Eixample                 8
# 8     2014                     2             Eixample                 9
# 9     2014                     2             Eixample                10
# 10    2014                     3       Sants-Montjuïc                11
# 11    2014                     3       Sants-Montjuïc                12
# ...

# %%
dframe.plot('Nom_Barri_baixa','Nombre',figsize=(12,4),marker='x',linestyle='-',linewidth=0.1,color='red')

# %%
#joint distribution 
sns.jointplot(data1,data2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2419d651fe3e> in <module>
#       1 #joint distribution
# ----> 2 sns.jointplot(data1,data2)
#
# NameError: name 'sns' is not defined
